# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(3)
# Out:
#          job_title_short            job_title        job_location  \
# 435300     Data Engineer  Azure Data Engineer          London, UK
# 582095  Business Analyst  Jigs&Tools Engineer  Astana, Kazakhstan
# 759771     Data Engineer          GIS Analyst     Tallahassee, FL
#
#                                  job_via job_schedule_type  \
# 435300                         via Melga         Full-time
# 582095  via Работа В Астане - HeadHunter         Full-time
# 759771                   via Trabajo.org         Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# 435300               False  United Kingdom 2023-02-25 16:51:54
# 582095               False      Kazakhstan 2023-02-13 10:01:21
# 759771               False         Georgia 2023-09-02 21:20:07
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 435300                   True                 False  United Kingdom
# 582095                  False                 False      Kazakhstan
# 759771                  False                 False   United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 435300        None              NaN              NaN
# 582095        None              NaN              NaN
# 759771        None              NaN              NaN
#
#                      company_name                             job_skills  \
# 435300  Nigel Frank International  ['python', 'sql', 'azure', 'pyspark']
# 582095                     Alstom                           ['assembly']
# 759771                   Crescens                     ['java', 'oracle']
#
#                                           job_type_skills
# 435300  {'cloud': ['azure'], 'libraries': ['pyspark'],...
# 582095                      {'programming': ['assembly']}
# 759771     {'cloud': ['oracle'], 'programming': ['java']}

# %%
df.sample(3, random_state=42)
# Out:
#               job_title_short                  job_title  \
# 502901   Senior Data Engineer       Senior Data Engineer
# 406337  Senior Data Scientist  Senior Analytics Engineer
# 659951          Data Engineer              Data Engineer
#
#                    job_location       job_via job_schedule_type  \
# 502901              St Paul, MN     via BeBee         Full-time
# 406337               London, UK  via LinkedIn         Full-time
# 659951  Newcastle upon Tyne, UK    via Indeed         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
#
#        salary_rate  salary_year_avg  salary_hour_avg   company_name  \
# 502901        None              NaN              NaN  ManpowerGroup
# 406337        None              NaN              NaN        Harnham
# 659951        None              NaN              NaN    Morgan King
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                               None
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                               None

# %%
df_original = df

# %%
 df_altered = df_original.copy()

# %%
median_salary = df_altered['salary_year_avg'].median()

df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

# %%
df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64
