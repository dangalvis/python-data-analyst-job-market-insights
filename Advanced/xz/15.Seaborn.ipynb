# %%
# !pip install seaborn


import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

sns.set_theme(style="ticks")

fig, ax = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# Formatter for $K labels
salary_formatter = ticker.FuncFormatter(lambda x, _: f'${int(x/1000)}K')

# ------- Top 10 Highest Paid Skills -------
sns.barplot(
    data=df_DA_top_pay.reset_index(),
    x="median",
    y="skills_list",          # or whatever your index column is named
    ax=ax[0],
    hue=None,
    palette="Blues_r"
)
ax[0].set_title("Top 10 Highest Paid Skills for Data Analysts")
ax[0].set_xlabel("")
ax[0].set_ylabel("")
ax[0].xaxis.set_major_formatter(salary_formatter)
ax[0].legend().remove()

# ------- Top 10 Most In-Demand Skills -------
# (here "median" is actually the count of postings – you can rename it to "count" earlier if you like)
sns.barplot(
    data=df_DA_skills.reset_index(),
    x="median",
    y="skills_list",
    ax=ax[1],
    hue=None,
    palette="Blues"
)
ax[1].set_title("Top 10 Most In-Demand Skills for Data Analysts")
ax[1].set_xlabel("Median Salary (USD)")
ax[1].set_ylabel("")
ax[1].xaxis.set_major_formatter(salary_formatter)
ax[1].legend().remove()

plt.tight_layout()
plt.show()
# Out:
# ...
# /var/folders/zv/b31nl3b17vg5l0d3gq707z4c0000gn/T/ipykernel_44405/2728769953.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /var/folders/zv/b31nl3b17vg5l0d3gq707z4c0000gn/T/ipykernel_44405/2728769953.py:28: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[0].legend().remove()
# /var/folders/zv/b31nl3b17vg5l0d3gq707z4c0000gn/T/ipykernel_44405/2728769953.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# ...

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

x = np.arange(len(skills))
y = np.zeros(len(skills))   # bars start at y=0
z = np.zeros(len(skills))   # bars start at z=0

dx = np.ones(len(skills))   # bar width
dy = np.ones(len(skills))   # bar depth
dz = values                 # bar height

ax.bar3d(x, y, z, dx, dy, dz, shade=True)

ax.set_xticks(x)
ax.set_xticklabels(skills, rotation=90)
ax.set_ylabel("")
ax.set_zlabel("Median Salary (USD)")
ax.set_title("Top 10 Highest Paid Skills - 3D Bar Chart")

plt.show()
